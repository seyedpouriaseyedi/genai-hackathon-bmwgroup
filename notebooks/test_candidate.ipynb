# %%
import os
import sys
import pandas as pd

PROJECT_ROOT = os.path.abspath("..")
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from agents.candidate_agent import score_candidates, get_signal_columns, get_competency_columns

hist_df = pd.read_csv(os.path.join(PROJECT_ROOT, "data/generated/historical_outcomes_raw.csv"))
curr_df = pd.read_csv(os.path.join(PROJECT_ROOT, "data/generated/current_applicants_raw.csv"))

hist_scored = score_candidates(hist_df)
curr_scored = score_candidates(curr_df)

print(hist_scored[get_signal_columns() + get_competency_columns()].head())
print()
print(curr_scored[get_signal_columns() + get_competency_columns()].head())
print()
print(hist_scored[get_competency_columns()].describe())
print()
print(curr_scored[get_competency_columns()].describe())
# Out:
#    signal_supply_chain_depth  signal_leadership  signal_internal_navigation  \
# 0                      55.50              56.00                        51.0
# 1                      56.50              63.00                        51.0
# 2                      72.92              42.50                        43.5
# 3                      84.25              76.25                        43.5
# 4                      37.08              45.75                        45.0
#
#    signal_cross_functional_coordination  signal_disruption_exposure  \
# 0                                  23.0                        25.0
# 1                                  30.0                        38.5
# 2                                  23.0                        23.5
# 3                                  32.0                        70.0
# 4                                  34.5                        16.5
#
#    signal_transformation_exposure  signal_operational_execution  \
# ...
